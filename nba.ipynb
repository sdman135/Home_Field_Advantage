# %% [markdown]
# # 2019 NBA Regular Season Evaluation

# %% [markdown]
# ## Import needed packages and config

# %%
import requests
import mysql.connector
import config
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Connect to MySql  and create database. Commented out once DB is created

# %%
cnx = mysql.connector.connect(
        host = config.host,
        user = config.user,
        password = config.password,
)
cursor = cnx.cursor(buffered=True)

# %% [markdown]
# ## (re)Connect to database, with database defined, to create table

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %% [markdown]
# ## Make API Call to grab 2019 NHL reg season data

# %%
api_key = config.nba_key
headers = {'Ocp-Apim-Subscription-Key' : '{}'.format(api_key)}

# %%
nba_data = []
url = 'https://api.sportsdata.io/v3/nba/scores/json/Games/2019'
response = requests.get(url, headers=headers)
data = response.json()
nba_data.append(data)

# %%
nba_data = nba_data[0] # data came back as list of lists of dictionaries.

# %%
nba_data
# Out:
# {'statusCode': 401,
#  'message': 'Access denied due to invalid subscription key. Make sure to provide a valid key for an active subscription.'}

# %%
parsed_games_nba = []
for game in nba_data:
    parsed_game = {}
    parsed_game['game_id'] = game['GameID']
    parsed_game['month'] = game['DateTime'][5:7]
    parsed_game['away_team'] = game['AwayTeam']
    parsed_game['away_team_score'] = game['AwayTeamScore']
    parsed_game['away_team_moneyline'] = game['PointSpreadAwayTeamMoneyLine']
    parsed_game['home_team'] = game['HomeTeam']
    parsed_game['home_team_score'] = game['HomeTeamScore']
    parsed_game['home_team_moneyline'] = game['PointSpreadHomeTeamMoneyLine']
    parsed_game['spread'] = game['PointSpread']
    parsed_games_nba.append(parsed_game)

# %%
parsed_games_nba
# Out:
# [{'game_id': 13093,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 9,
#   'away_team_moneyline': 242,
#   'home_team': 'OTT',
#   'home_team_score': 5,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 13094,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 3,
#   'away_team_moneyline': -242,
#   'home_team': 'WAS',
#   'home_team_score': 7,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13095,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 4,
#   'away_team_moneyline': -236,
#   'home_team': 'ANA',
#   'home_team_score': 3,
#   'home_team_moneyline': 216,
#   'spread': -1.7},
#  {'game_id': 13096,
#   'month': '10',
#   'away_team': 'MON',
#   'away_team_score': 3,
#   'away_team_moneyline': -144,
#   'home_team': 'TOR',
#   'home_team_score': 4,
#   'home_team_moneyline': 132,
#   'spread': -1.7},
#  {'game_id': 13097,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 0,
#   'away_team_moneyline': -306,
#   'home_team': 'WAS',
#   'home_team_score': 9,
#   'home_team_moneyline': 283,
#   'spread': -1.7},
#  {'game_id': 13098,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': 242,
#   'home_team': 'VAN',
#   'home_team_score': 7,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 13099,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 7,
#   'away_team_moneyline': -196,
#   'home_team': 'SJ',
#   'home_team_score': 3,
#   'home_team_moneyline': 184,
#   'spread': -1.7},
#  {'game_id': 13100,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 5,
#   'away_team_moneyline': 230,
#   'home_team': 'BUF',
#   'home_team_score': 0,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13101,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 3,
#   'away_team_moneyline': -219,
#   'home_team': 'CAR',
#   'home_team_score': 1,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13102,
#   'month': '10',
#   'away_team': 'NAS',
#   'away_team_score': 4,
#   'away_team_moneyline': 213,
#   'home_team': 'NYR',
#   'home_team_score': 3,
#   'home_team_moneyline': -230,
#   'spread': 2.0},
#  {'game_id': 13103,
#   'month': '10',
#   'away_team': 'WAS',
#   'away_team_score': 8,
#   'away_team_moneyline': -219,
#   'home_team': 'PIT',
#   'home_team_score': 9,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13104,
#   'month': '10',
#   'away_team': 'CBJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 224,
#   'home_team': 'DET',
#   'home_team_score': 3,
#   'home_team_moneyline': -247,
#   'spread': 2.0},
#  {'game_id': 13105,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 5,
#   'away_team_moneyline': 270,
#   'home_team': 'OTT',
#   'home_team_score': 4,
#   'home_team_moneyline': -294,
#   'spread': 2.0},
#  {'game_id': 13106,
#   'month': '10',
#   'away_team': 'WPG',
#   'away_team_score': 7,
#   'away_team_moneyline': -351,
#   'home_team': 'STL',
#   'home_team_score': 1,
#   'home_team_moneyline': 317,
#   'spread': -1.7},
#  {'game_id': 13107,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 0,
#   'away_team_moneyline': -190,
#   'home_team': 'DAL',
#   'home_team_score': 4,
#   'home_team_moneyline': 178,
#   'spread': -1.7},
#  {'game_id': 13108,
#   'month': '10',
#   'away_team': 'MIN',
#   'away_team_score': 1,
#   'away_team_moneyline': -322,
#   'home_team': 'COL',
#   'home_team_score': 5,
#   'home_team_moneyline': 294,
#   'spread': -1.7},
#  {'game_id': 13109,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 7,
#   'away_team_moneyline': -213,
#   'home_team': 'VEG',
#   'home_team_score': 3,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13110,
#   'month': '10',
#   'away_team': 'CAR',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'CBJ',
#   'home_team_score': 1,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13111,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 282,
#   'home_team': 'LA',
#   'home_team_score': 3,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 13112,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': 294,
#   'home_team': 'NJ',
#   'home_team_score': 7,
#   'home_team_moneyline': -322,
#   'spread': 2.0},
#  {'game_id': 13113,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 1,
#   'away_team_moneyline': -274,
#   'home_team': 'BUF',
#   'home_team_score': 4,
#   'home_team_moneyline': 251,
#   'spread': -1.7},
#  {'game_id': 13114,
#   'month': '10',
#   'away_team': 'WPG',
#   'away_team_score': 1,
#   'away_team_moneyline': 299,
#   'home_team': 'DAL',
#   'home_team_score': 7,
#   'home_team_moneyline': -334,
#   'spread': 2.0},
#  {'game_id': 13115,
#   'month': '10',
#   'away_team': 'NAS',
#   'away_team_score': 5,
#   'away_team_moneyline': 224,
#   'home_team': 'NYI',
#   'home_team_score': 4,
#   'home_team_moneyline': -247,
#   'spread': 2.0},
#  {'game_id': 13116,
#   'month': '10',
#   'away_team': 'MON',
#   'away_team_score': 7,
#   'away_team_moneyline': -155,
#   'home_team': 'PIT',
#   'home_team_score': 1,
#   'home_team_moneyline': 144,
#   'spread': -1.7},
#  {'game_id': 13117,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 1,
#   'away_team_moneyline': -196,
#   'home_team': 'TB',
#   'home_team_score': 3,
#   'home_team_moneyline': 184,
#   'spread': -1.7},
#  {'game_id': 13118,
#   'month': '10',
#   'away_team': 'OTT',
#   'away_team_score': 7,
#   'away_team_moneyline': 115,
#   'home_team': 'TOR',
#   'home_team_score': 4,
#   'home_team_moneyline': -127,
#   'spread': -1.7},
#  {'game_id': 13119,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 7,
#   'away_team_moneyline': -204,
#   'home_team': 'STL',
#   'home_team_score': 5,
#   'home_team_moneyline': 191,
#   'spread': -1.7},
#  {'game_id': 13120,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 3,
#   'away_team_moneyline': -298,
#   'home_team': 'MIN',
#   'home_team_score': 1,
#   'home_team_moneyline': 275,
#   'spread': -1.7},
#  {'game_id': 13121,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 5,
#   'away_team_moneyline': -184,
#   'home_team': 'CGY',
#   'home_team_score': 9,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13122,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 3,
#   'away_team_moneyline': -322,
#   'home_team': 'COL',
#   'home_team_score': 7,
#   'home_team_moneyline': 294,
#   'spread': -1.7},
#  {'game_id': 13123,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': 282,
#   'home_team': 'ARI',
#   'home_team_score': 0,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 13124,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 7,
#   'away_team_moneyline': -178,
#   'home_team': 'CAR',
#   'home_team_score': 11,
#   'home_team_moneyline': 167,
#   'spread': -1.7},
#  {'game_id': 13125,
#   'month': '10',
#   'away_team': 'TOR',
#   'away_team_score': 9,
#   'away_team_moneyline': 230,
#   'home_team': 'CHI',
#   'home_team_score': 8,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13126,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 3,
#   'away_team_moneyline': -184,
#   'home_team': 'LA',
#   'home_team_score': 5,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13127,
#   'month': '10',
#   'away_team': 'OTT',
#   'away_team_score': 4,
#   'away_team_moneyline': -134,
#   'home_team': 'BOS',
#   'home_team_score': 8,
#   'home_team_moneyline': 122,
#   'spread': -1.7},
#  {'game_id': 13128,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 0,
#   'away_team_moneyline': 193,
#   'home_team': 'NYI',
#   'home_team_score': 5,
#   'home_team_moneyline': -207,
#   'spread': 2.0},
#  {'game_id': 13129,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 3,
#   'away_team_moneyline': 230,
#   'home_team': 'BUF',
#   'home_team_score': 5,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13130,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 3,
#   'away_team_moneyline': -178,
#   'home_team': 'ANA',
#   'home_team_score': 4,
#   'home_team_moneyline': 167,
#   'spread': -1.7},
#  {'game_id': 13131,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 4,
#   'away_team_moneyline': -184,
#   'home_team': 'CAR',
#   'home_team_score': 7,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13132,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 11,
#   'away_team_moneyline': -299,
#   'home_team': 'PHI',
#   'home_team_score': 3,
#   'home_team_moneyline': 276,
#   'spread': -1.7},
#  {'game_id': 13133,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': -242,
#   'home_team': 'CBJ',
#   'home_team_score': 7,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13134,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 4,
#   'away_team_moneyline': -219,
#   'home_team': 'NAS',
#   'home_team_score': 0,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13135,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -188,
#   'home_team': 'WPG',
#   'home_team_score': 3,
#   'home_team_moneyline': 176,
#   'spread': -1.7},
#  {'game_id': 13136,
#   'month': '10',
#   'away_team': 'TOR',
#   'away_team_score': 9,
#   'away_team_moneyline': -276,
#   'home_team': 'DAL',
#   'home_team_score': 5,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 13137,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 1,
#   'away_team_moneyline': -213,
#   'home_team': 'BOS',
#   'home_team_score': 5,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13138,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 8,
#   'away_team_moneyline': 265,
#   'home_team': 'BUF',
#   'home_team_score': 1,
#   'home_team_moneyline': -288,
#   'spread': 2.0},
#  {'game_id': 13139,
#   'month': '10',
#   'away_team': 'WAS',
#   'away_team_score': 0,
#   'away_team_moneyline': -311,
#   'home_team': 'NJ',
#   'home_team_score': 8,
#   'home_team_moneyline': 285,
#   'spread': -1.7},
#  {'game_id': 13140,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 3,
#   'away_team_moneyline': 219,
#   'home_team': 'NYR',
#   'home_team_score': 4,
#   'home_team_moneyline': -242,
#   'spread': 2.0},
#  {'game_id': 13141,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 3,
#   'away_team_moneyline': -190,
#   'home_team': 'PIT',
#   'home_team_score': 5,
#   'home_team_moneyline': 178,
#   'spread': -1.7},
#  {'game_id': 13142,
#   'month': '10',
#   'away_team': 'CBJ',
#   'away_team_score': 7,
#   'away_team_moneyline': -294,
#   'home_team': 'FLA',
#   'home_team_score': 5,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 13143,
#   'month': '10',
#   'away_team': 'TOR',
#   'away_team_score': 7,
#   'away_team_moneyline': 184,
#   'home_team': 'DET',
#   'home_team_score': 4,
#   'home_team_moneyline': -196,
#   'spread': 2.0},
#  {'game_id': 13144,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 4,
#   'away_team_moneyline': -317,
#   'home_team': 'MON',
#   'home_team_score': 0,
#   'home_team_moneyline': 288,
#   'spread': -1.7},
#  {'game_id': 13145,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 5,
#   'away_team_moneyline': -138,
#   'home_team': 'TB',
#   'home_team_score': 1,
#   'home_team_moneyline': 127,
#   'spread': -1.7},
#  {'game_id': 13146,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 4,
#   'away_team_moneyline': -298,
#   'home_team': 'STL',
#   'home_team_score': 7,
#   'home_team_moneyline': 275,
#   'spread': -1.7},
#  {'game_id': 13147,
#   'month': '10',
#   'away_team': 'WPG',
#   'away_team_score': 0,
#   'away_team_moneyline': -276,
#   'home_team': 'NAS',
#   'home_team_score': 4,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 13148,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'MIN',
#   'home_team_score': 5,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13149,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': 276,
#   'home_team': 'NYR',
#   'home_team_score': 1,
#   'home_team_moneyline': -299,
#   'spread': 2.0},
#  {'game_id': 13150,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 1,
#   'away_team_moneyline': -305,
#   'home_team': 'PHI',
#   'home_team_score': 0,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 13151,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': 213,
#   'home_team': 'OTT',
#   'home_team_score': 7,
#   'home_team_moneyline': -230,
#   'spread': 2.0},
#  {'game_id': 13152,
#   'month': '10',
#   'away_team': 'CAR',
#   'away_team_score': 7,
#   'away_team_moneyline': -259,
#   'home_team': 'MIN',
#   'home_team_score': 5,
#   'home_team_moneyline': 236,
#   'spread': -1.7},
#  {'game_id': 13153,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 3,
#   'away_team_moneyline': -150,
#   'home_team': 'BOS',
#   'home_team_score': 11,
#   'home_team_moneyline': 138,
#   'spread': -1.7},
#  {'game_id': 13154,
#   'month': '10',
#   'away_team': 'PIT',
#   'away_team_score': 4,
#   'away_team_moneyline': 213,
#   'home_team': 'MON',
#   'home_team_score': 5,
#   'home_team_moneyline': -230,
#   'spread': 2.0},
#  {'game_id': 13155,
#   'month': '10',
#   'away_team': 'CBJ',
#   'away_team_score': 3,
#   'away_team_moneyline': -205,
#   'home_team': 'TB',
#   'home_team_score': 11,
#   'home_team_moneyline': 192,
#   'spread': -1.7},
#  {'game_id': 13156,
#   'month': '10',
#   'away_team': 'TOR',
#   'away_team_score': 5,
#   'away_team_moneyline': -294,
#   'home_team': 'WAS',
#   'home_team_score': 3,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 13157,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 4,
#   'away_team_moneyline': -184,
#   'home_team': 'FLA',
#   'home_team_score': 3,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13158,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 4,
#   'away_team_moneyline': -219,
#   'home_team': 'DAL',
#   'home_team_score': 7,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13159,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 3,
#   'away_team_moneyline': -173,
#   'home_team': 'NAS',
#   'home_team_score': 7,
#   'home_team_moneyline': 161,
#   'spread': -1.7},
#  {'game_id': 13160,
#   'month': '10',
#   'away_team': 'STL',
#   'away_team_score': 4,
#   'away_team_moneyline': -345,
#   'home_team': 'CHI',
#   'home_team_score': 5,
#   'home_team_moneyline': 311,
#   'spread': -1.7},
#  {'game_id': 13161,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 4,
#   'away_team_moneyline': -242,
#   'home_team': 'ARI',
#   'home_team_score': 0,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13162,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 4,
#   'away_team_moneyline': -259,
#   'home_team': 'COL',
#   'home_team_score': 3,
#   'home_team_moneyline': 236,
#   'spread': -1.7},
#  {'game_id': 13163,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 3,
#   'away_team_moneyline': 285,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': -311,
#   'spread': 2.0},
#  {'game_id': 13164,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 4,
#   'away_team_moneyline': -242,
#   'home_team': 'STL',
#   'home_team_score': 3,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13165,
#   'month': '10',
#   'away_team': 'CAR',
#   'away_team_score': 1,
#   'away_team_moneyline': -201,
#   'home_team': 'WPG',
#   'home_team_score': 4,
#   'home_team_moneyline': 190,
#   'spread': -1.7},
#  {'game_id': 13166,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'MON',
#   'home_team_score': 9,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13167,
#   'month': '10',
#   'away_team': 'DAL',
#   'away_team_score': 1,
#   'away_team_moneyline': 193,
#   'home_team': 'OTT',
#   'home_team_score': 5,
#   'home_team_moneyline': -207,
#   'spread': 2.0},
#  {'game_id': 13168,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -196,
#   'home_team': 'TOR',
#   'home_team_score': 5,
#   'home_team_moneyline': 184,
#   'spread': -1.7},
#  {'game_id': 13169,
#   'month': '10',
#   'away_team': 'MIN',
#   'away_team_score': 3,
#   'away_team_moneyline': -184,
#   'home_team': 'NAS',
#   'home_team_score': 5,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13170,
#   'month': '10',
#   'away_team': 'DAL',
#   'away_team_score': 0,
#   'away_team_moneyline': -265,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13171,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': 242,
#   'home_team': 'NYR',
#   'home_team_score': 4,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 13172,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 7,
#   'away_team_moneyline': -288,
#   'home_team': 'PHI',
#   'home_team_score': 8,
#   'home_team_moneyline': 265,
#   'spread': -1.7},
#  {'game_id': 13173,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 4,
#   'away_team_moneyline': -150,
#   'home_team': 'PIT',
#   'home_team_score': 3,
#   'home_team_moneyline': 138,
#   'spread': -1.7},
#  {'game_id': 13174,
#   'month': '10',
#   'away_team': 'CAR',
#   'away_team_score': 3,
#   'away_team_moneyline': -230,
#   'home_team': 'TB',
#   'home_team_score': 5,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13175,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 7,
#   'away_team_moneyline': -188,
#   'home_team': 'WPG',
#   'home_team_score': 5,
#   'home_team_moneyline': 176,
#   'spread': -1.7},
#  {'game_id': 13176,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 1,
#   'away_team_moneyline': -224,
#   'home_team': 'MIN',
#   'home_team_score': 3,
#   'home_team_moneyline': 207,
#   'spread': -1.7},
#  {'game_id': 13177,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 1,
#   'away_team_moneyline': -176,
#   'home_team': 'VEG',
#   'home_team_score': 5,
#   'home_team_moneyline': 165,
#   'spread': -1.7},
#  {'game_id': 13178,
#   'month': '10',
#   'away_team': 'STL',
#   'away_team_score': 3,
#   'away_team_moneyline': 296,
#   'home_team': 'MON',
#   'home_team_score': 4,
#   'home_team_moneyline': -328,
#   'spread': 2.0},
#  {'game_id': 13179,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 4,
#   'away_team_moneyline': -138,
#   'home_team': 'WAS',
#   'home_team_score': 5,
#   'home_team_moneyline': 127,
#   'spread': -1.7},
#  {'game_id': 13180,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 3,
#   'away_team_moneyline': -322,
#   'home_team': 'CGY',
#   'home_team_score': 7,
#   'home_team_moneyline': 294,
#   'spread': -1.7},
#  {'game_id': 13181,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 1,
#   'away_team_moneyline': -253,
#   'home_team': 'ANA',
#   'home_team_score': 5,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13182,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 7,
#   'away_team_moneyline': -253,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13183,
#   'month': '10',
#   'away_team': 'PIT',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'TOR',
#   'home_team_score': 0,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13184,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -242,
#   'home_team': 'CBJ',
#   'home_team_score': 8,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13185,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 1,
#   'away_team_moneyline': -123,
#   'home_team': 'TB',
#   'home_team_score': 4,
#   'home_team_moneyline': -119,
#   'spread': -1.7},
#  {'game_id': 13186,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 1,
#   'away_team_moneyline': -144,
#   'home_team': 'WPG',
#   'home_team_score': 5,
#   'home_team_moneyline': 132,
#   'spread': -1.7},
#  {'game_id': 13187,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 5,
#   'away_team_moneyline': -219,
#   'home_team': 'CHI',
#   'home_team_score': 1,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13188,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 3,
#   'away_team_moneyline': 259,
#   'home_team': 'EDM',
#   'home_team_score': 4,
#   'home_team_moneyline': -282,
#   'spread': 2.0},
#  {'game_id': 13189,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 9,
#   'away_team_moneyline': -219,
#   'home_team': 'LA',
#   'home_team_score': 3,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13190,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 1,
#   'away_team_moneyline': -146,
#   'home_team': 'SJ',
#   'home_team_score': 7,
#   'home_team_moneyline': 135,
#   'spread': -1.7},
#  {'game_id': 13191,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 8,
#   'away_team_moneyline': -242,
#   'home_team': 'WAS',
#   'home_team_score': 7,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13192,
#   'month': '10',
#   'away_team': 'MIN',
#   'away_team_score': 4,
#   'away_team_moneyline': -247,
#   'home_team': 'DAL',
#   'home_team_score': 1,
#   'home_team_moneyline': 224,
#   'spread': -1.7},
#  {'game_id': 13193,
#   'month': '10',
#   'away_team': 'NAS',
#   'away_team_score': 7,
#   'away_team_moneyline': 276,
#   'home_team': 'CGY',
#   'home_team_score': 4,
#   'home_team_moneyline': -299,
#   'spread': 2.0},
#  {'game_id': 13194,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 4,
#   'away_team_moneyline': -253,
#   'home_team': 'CAR',
#   'home_team_score': 1,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13195,
#   'month': '10',
#   'away_team': 'NJ',
#   'away_team_score': 3,
#   'away_team_moneyline': -294,
#   'home_team': 'PHI',
#   'home_team_score': 7,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 13196,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 4,
#   'away_team_moneyline': -184,
#   'home_team': 'WPG',
#   'home_team_score': 7,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13197,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 7,
#   'away_team_moneyline': -201,
#   'home_team': 'LA',
#   'home_team_score': 1,
#   'home_team_moneyline': 190,
#   'spread': -1.7},
#  {'game_id': 13198,
#   'month': '10',
#   'away_team': 'MON',
#   'away_team_score': 4,
#   'away_team_moneyline': 276,
#   'home_team': 'OTT',
#   'home_team_score': 5,
#   'home_team_moneyline': -299,
#   'spread': 2.0},
#  {'game_id': 13199,
#   'month': '10',
#   'away_team': 'STL',
#   'away_team_score': 5,
#   'away_team_moneyline': -213,
#   'home_team': 'TOR',
#   'home_team_score': 1,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13200,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 5,
#   'away_team_moneyline': -178,
#   'home_team': 'FLA',
#   'home_team_score': 4,
#   'home_team_moneyline': 167,
#   'spread': -1.7},
#  {'game_id': 13201,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 5,
#   'away_team_moneyline': -242,
#   'home_team': 'CBJ',
#   'home_team_score': 1,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13202,
#   'month': '10',
#   'away_team': 'TB',
#   'away_team_score': 5,
#   'away_team_moneyline': 236,
#   'home_team': 'MIN',
#   'home_team_score': 7,
#   'home_team_moneyline': -259,
#   'spread': 2.0},
#  {'game_id': 13203,
#   'month': '10',
#   'away_team': 'NAS',
#   'away_team_score': 4,
#   'away_team_moneyline': 253,
#   'home_team': 'EDM',
#   'home_team_score': 0,
#   'home_team_moneyline': -276,
#   'spread': 2.0},
#  {'game_id': 13204,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 1,
#   'away_team_moneyline': 201,
#   'home_team': 'VAN',
#   'home_team_score': 3,
#   'home_team_moneyline': -219,
#   'spread': 2.0},
#  {'game_id': 13205,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': -213,
#   'home_team': 'VEG',
#   'home_team_score': 4,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13206,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 1,
#   'away_team_moneyline': -155,
#   'home_team': 'SJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 144,
#   'spread': -1.7},
#  {'game_id': 13207,
#   'month': '10',
#   'away_team': 'TB',
#   'away_team_score': 8,
#   'away_team_moneyline': 230,
#   'home_team': 'CHI',
#   'home_team_score': 4,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13208,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 5,
#   'away_team_moneyline': 236,
#   'home_team': 'NYR',
#   'home_team_score': 1,
#   'home_team_moneyline': -259,
#   'spread': 2.0},
#  {'game_id': 13209,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 5,
#   'away_team_moneyline': -242,
#   'home_team': 'ANA',
#   'home_team_score': 3,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13210,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 5,
#   'away_team_moneyline': -282,
#   'home_team': 'PHI',
#   'home_team_score': 1,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 13211,
#   'month': '10',
#   'away_team': 'CAR',
#   'away_team_score': 4,
#   'away_team_moneyline': 213,
#   'home_team': 'DET',
#   'home_team_score': 1,
#   'home_team_moneyline': -230,
#   'spread': 2.0},
#  {'game_id': 13212,
#   'month': '10',
#   'away_team': 'STL',
#   'away_team_score': 5,
#   'away_team_moneyline': -230,
#   'home_team': 'WPG',
#   'home_team_score': 7,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13213,
#   'month': '10',
#   'away_team': 'WAS',
#   'away_team_score': 7,
#   'away_team_moneyline': 224,
#   'home_team': 'VAN',
#   'home_team_score': 3,
#   'home_team_moneyline': -247,
#   'spread': 2.0},
#  {'game_id': 13214,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 3,
#   'away_team_moneyline': 242,
#   'home_team': 'NYR',
#   'home_team_score': 7,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 13215,
#   'month': '10',
#   'away_team': 'ARI',
#   'away_team_score': 5,
#   'away_team_moneyline': -190,
#   'home_team': 'CBJ',
#   'home_team_score': 1,
#   'home_team_moneyline': 178,
#   'spread': -1.7},
#  {'game_id': 13216,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': 299,
#   'home_team': 'MON',
#   'home_team_score': 4,
#   'home_team_moneyline': -334,
#   'spread': 2.0},
#  {'game_id': 13217,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 5,
#   'away_team_moneyline': 207,
#   'home_team': 'OTT',
#   'home_team_score': 1,
#   'home_team_moneyline': -224,
#   'spread': 2.0},
#  {'game_id': 13218,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 7,
#   'away_team_moneyline': -270,
#   'home_team': 'NAS',
#   'home_team_score': 5,
#   'home_team_moneyline': 247,
#   'spread': -1.7},
#  {'game_id': 13219,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': -259,
#   'home_team': 'CHI',
#   'home_team_score': 4,
#   'home_team_moneyline': 236,
#   'spread': -1.7},
#  {'game_id': 13220,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 3,
#   'away_team_moneyline': -242,
#   'home_team': 'DAL',
#   'home_team_score': 5,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13221,
#   'month': '10',
#   'away_team': 'PIT',
#   'away_team_score': 8,
#   'away_team_moneyline': 259,
#   'home_team': 'EDM',
#   'home_team_score': 7,
#   'home_team_moneyline': -282,
#   'spread': 2.0},
#  {'game_id': 13222,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 4,
#   'away_team_moneyline': -322,
#   'home_team': 'NYI',
#   'home_team_score': 3,
#   'home_team_moneyline': 294,
#   'spread': -1.7},
#  {'game_id': 13223,
#   'month': '10',
#   'away_team': 'TOR',
#   'away_team_score': 5,
#   'away_team_moneyline': -265,
#   'home_team': 'WPG',
#   'home_team_score': 3,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13224,
#   'month': '10',
#   'away_team': 'TB',
#   'away_team_score': 1,
#   'away_team_moneyline': 265,
#   'home_team': 'COL',
#   'home_team_score': 0,
#   'home_team_moneyline': -288,
#   'spread': 2.0},
#  {'game_id': 13225,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 4,
#   'away_team_moneyline': -132,
#   'home_team': 'VEG',
#   'home_team_score': 3,
#   'home_team_moneyline': 121,
#   'spread': -1.7},
#  {'game_id': 13226,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 0,
#   'away_team_moneyline': -224,
#   'home_team': 'BOS',
#   'home_team_score': 4,
#   'home_team_moneyline': 207,
#   'spread': -1.7},
#  {'game_id': 13227,
#   'month': '10',
#   'away_team': 'MON',
#   'away_team_score': 4,
#   'away_team_moneyline': -288,
#   'home_team': 'BUF',
#   'home_team_score': 5,
#   'home_team_moneyline': 265,
#   'spread': -1.7},
#  {'game_id': 13228,
#   'month': '10',
#   'away_team': 'NAS',
#   'away_team_score': 5,
#   'away_team_moneyline': 270,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': -294,
#   'spread': 2.0},
#  {'game_id': 13229,
#   'month': '10',
#   'away_team': 'CBJ',
#   'away_team_score': 9,
#   'away_team_moneyline': -247,
#   'home_team': 'STL',
#   'home_team_score': 5,
#   'home_team_moneyline': 224,
#   'spread': -1.7},
#  {'game_id': 13230,
#   'month': '10',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -214,
#   'home_team': 'MIN',
#   'home_team_score': 5,
#   'home_team_moneyline': 197,
#   'spread': -1.7},
#  {'game_id': 13231,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 1,
#   'away_team_moneyline': -242,
#   'home_team': 'CHI',
#   'home_team_score': 5,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13232,
#   'month': '10',
#   'away_team': 'ANA',
#   'away_team_score': 3,
#   'away_team_moneyline': -228,
#   'home_team': 'DAL',
#   'home_team_score': 7,
#   'home_team_moneyline': 211,
#   'spread': -1.7},
#  {'game_id': 13233,
#   'month': '10',
#   'away_team': 'PIT',
#   'away_team_score': 10,
#   'away_team_moneyline': -287,
#   'home_team': 'CGY',
#   'home_team_score': 1,
#   'home_team_moneyline': 264,
#   'spread': -1.7},
#  {'game_id': 13234,
#   'month': '10',
#   'away_team': 'WAS',
#   'away_team_score': 1,
#   'away_team_moneyline': 270,
#   'home_team': 'EDM',
#   'home_team_score': 5,
#   'home_team_moneyline': -294,
#   'spread': 2.0},
#  {'game_id': 13235,
#   'month': '10',
#   'away_team': 'VAN',
#   'away_team_score': 1,
#   'away_team_moneyline': -173,
#   'home_team': 'ARI',
#   'home_team_score': 5,
#   'home_team_moneyline': 161,
#   'spread': -1.7},
#  {'game_id': 13236,
#   'month': '10',
#   'away_team': 'TB',
#   'away_team_score': 4,
#   'away_team_moneyline': 294,
#   'home_team': 'VEG',
#   'home_team_score': 3,
#   'home_team_moneyline': -322,
#   'spread': 2.0},
#  {'game_id': 13237,
#   'month': '10',
#   'away_team': 'WPG',
#   'away_team_score': 3,
#   'away_team_moneyline': 207,
#   'home_team': 'DET',
#   'home_team_score': 1,
#   'home_team_moneyline': -224,
#   'spread': 2.0},
#  {'game_id': 13238,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 311,
#   'home_team': 'CAR',
#   'home_team_score': 5,
#   'home_team_moneyline': -345,
#   'spread': 2.0},
#  {'game_id': 13239,
#   'month': '10',
#   'away_team': 'OTT',
#   'away_team_score': 4,
#   'away_team_moneyline': -171,
#   'home_team': 'COL',
#   'home_team_score': 8,
#   'home_team_moneyline': 160,
#   'spread': -1.7},
#  {'game_id': 13240,
#   'month': '10',
#   'away_team': 'FLA',
#   'away_team_score': 3,
#   'away_team_moneyline': -276,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 13241,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 8,
#   'away_team_moneyline': -230,
#   'home_team': 'PHI',
#   'home_team_score': 1,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13242,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 7,
#   'away_team_moneyline': -180,
#   'home_team': 'NAS',
#   'home_team_score': 4,
#   'home_team_moneyline': 168,
#   'spread': -1.7},
#  {'game_id': 13243,
#   'month': '10',
#   'away_team': 'WAS',
#   'away_team_score': 5,
#   'away_team_moneyline': -305,
#   'home_team': 'CGY',
#   'home_team_score': 4,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 13244,
#   'month': '10',
#   'away_team': 'MON',
#   'away_team_score': 4,
#   'away_team_moneyline': -201,
#   'home_team': 'BOS',
#   'home_team_score': 0,
#   'home_team_moneyline': 190,
#   'spread': -1.7},
#  {'game_id': 13245,
#   'month': '10',
#   'away_team': 'WPG',
#   'away_team_score': 3,
#   'away_team_moneyline': -242,
#   'home_team': 'TOR',
#   'home_team_score': 4,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13246,
#   'month': '10',
#   'away_team': 'BUF',
#   'away_team_score': 5,
#   'away_team_moneyline': -182,
#   'home_team': 'CBJ',
#   'home_team_score': 7,
#   'home_team_moneyline': 170,
#   'spread': -1.7},
#  {'game_id': 13247,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -253,
#   'home_team': 'STL',
#   'home_team_score': 9,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13248,
#   'month': '10',
#   'away_team': 'COL',
#   'away_team_score': 3,
#   'away_team_moneyline': -228,
#   'home_team': 'MIN',
#   'home_team_score': 4,
#   'home_team_moneyline': 211,
#   'spread': -1.7},
#  {'game_id': 13249,
#   'month': '10',
#   'away_team': 'TB',
#   'away_team_score': 1,
#   'away_team_moneyline': 270,
#   'home_team': 'ARI',
#   'home_team_score': 9,
#   'home_team_moneyline': -294,
#   'spread': 2.0},
#  {'game_id': 13250,
#   'month': '10',
#   'away_team': 'PIT',
#   'away_team_score': 7,
#   'away_team_moneyline': 178,
#   'home_team': 'VAN',
#   'home_team_score': 0,
#   'home_team_moneyline': -190,
#   'spread': 2.0},
#  {'game_id': 13251,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 4,
#   'away_team_moneyline': -213,
#   'home_team': 'LA',
#   'home_team_score': 5,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13252,
#   'month': '10',
#   'away_team': 'DAL',
#   'away_team_score': 3,
#   'away_team_moneyline': 213,
#   'home_team': 'DET',
#   'home_team_score': 5,
#   'home_team_moneyline': -230,
#   'spread': 2.0},
#  {'game_id': 13253,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 3,
#   'away_team_moneyline': -160,
#   'home_team': 'CAR',
#   'home_team_score': 1,
#   'home_team_moneyline': 148,
#   'spread': -1.7},
#  {'game_id': 13254,
#   'month': '10',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': -340,
#   'home_team': 'CHI',
#   'home_team_score': 1,
#   'home_team_moneyline': 305,
#   'spread': -1.7},
#  {'game_id': 13255,
#   'month': '10',
#   'away_team': 'SJ',
#   'away_team_score': 5,
#   'away_team_moneyline': 224,
#   'home_team': 'ANA',
#   'home_team_score': 4,
#   'home_team_moneyline': -247,
#   'spread': 2.0},
#  {'game_id': 13256,
#   'month': '10',
#   'away_team': 'OTT',
#   'away_team_score': 4,
#   'away_team_moneyline': -144,
#   'home_team': 'VEG',
#   'home_team_score': 5,
#   'home_team_moneyline': 132,
#   'spread': -1.7},
#  {'game_id': 13257,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 4,
#   'away_team_moneyline': -236,
#   'home_team': 'TOR',
#   'home_team_score': 1,
#   'home_team_moneyline': 216,
#   'spread': -1.7},
#  {'game_id': 13258,
#   'month': '10',
#   'away_team': 'MIN',
#   'away_team_score': 3,
#   'away_team_moneyline': 195,
#   'home_team': 'VAN',
#   'home_team_score': 7,
#   'home_team_moneyline': -209,
#   'spread': 2.0},
#  {'game_id': 13259,
#   'month': '10',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': -294,
#   'home_team': 'BUF',
#   'home_team_score': 1,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 13260,
#   'month': '10',
#   'away_team': 'BOS',
#   'away_team_score': 4,
#   'away_team_moneyline': -288,
#   'home_team': 'CAR',
#   'home_team_score': 3,
#   'home_team_moneyline': 265,
#   'spread': -1.7},
#  {'game_id': 13261,
#   'month': '10',
#   'away_team': 'NYI',
#   'away_team_score': 8,
#   'away_team_moneyline': -173,
#   'home_team': 'PIT',
#   'home_team_score': 4,
#   'home_team_moneyline': 161,
#   'spread': -1.7},
#  {'game_id': 13262,
#   'month': '10',
#   'away_team': 'DET',
#   'away_team_score': 7,
#   'away_team_moneyline': -161,
#   'home_team': 'CBJ',
#   'home_team_score': 4,
#   'home_team_moneyline': 150,
#   'spread': -1.7},
#  {'game_id': 13263,
#   'month': '10',
#   'away_team': 'DAL',
#   'away_team_score': 5,
#   'away_team_moneyline': -340,
#   'home_team': 'MON',
#   'home_team_score': 1,
#   'home_team_moneyline': 305,
#   'spread': -1.7},
#  {'game_id': 13264,
#   'month': '10',
#   'away_team': 'NJ',
#   'away_team_score': 4,
#   'away_team_moneyline': -224,
#   'home_team': 'TB',
#   'home_team_score': 11,
#   'home_team_moneyline': 207,
#   'spread': -1.7},
#  {'game_id': 13265,
#   'month': '10',
#   'away_team': 'VEG',
#   'away_team_score': 1,
#   'away_team_moneyline': -213,
#   'home_team': 'NAS',
#   'home_team_score': 5,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13266,
#   'month': '10',
#   'away_team': 'MIN',
#   'away_team_score': 5,
#   'away_team_moneyline': -270,
#   'home_team': 'EDM',
#   'home_team_score': 4,
#   'home_team_moneyline': 247,
#   'spread': -1.7},
#  {'game_id': 13267,
#   'month': '10',
#   'away_team': 'OTT',
#   'away_team_score': 1,
#   'away_team_moneyline': -184,
#   'home_team': 'ARI',
#   'home_team_score': 7,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13268,
#   'month': '10',
#   'away_team': 'PHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -305,
#   'home_team': 'ANA',
#   'home_team_score': 3,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 13269,
#   'month': '10',
#   'away_team': 'NYR',
#   'away_team_score': 5,
#   'away_team_moneyline': -127,
#   'home_team': 'SJ',
#   'home_team_score': 4,
#   'home_team_moneyline': 115,
#   'spread': -1.7},
#  {'game_id': 13270,
#   'month': '10',
#   'away_team': 'CHI',
#   'away_team_score': 3,
#   'away_team_moneyline': 253,
#   'home_team': 'VAN',
#   'home_team_score': 5,
#   'home_team_moneyline': -276,
#   'spread': 2.0},
#  {'game_id': 13271,
#   'month': '11',
#   'away_team': 'WPG',
#   'away_team_score': 5,
#   'away_team_moneyline': 253,
#   'home_team': 'FLA',
#   'home_team_score': 3,
#   'home_team_moneyline': -276,
#   'spread': 2.0},
#  {'game_id': 13272,
#   'month': '11',
#   'away_team': 'PIT',
#   'away_team_score': 3,
#   'away_team_moneyline': 207,
#   'home_team': 'NYI',
#   'home_team_score': 4,
#   'home_team_moneyline': -224,
#   'spread': 2.0},
#  {'game_id': 13273,
#   'month': '11',
#   'away_team': 'DAL',
#   'away_team_score': 3,
#   'away_team_moneyline': -229,
#   'home_team': 'TOR',
#   'home_team_score': 1,
#   'home_team_moneyline': 212,
#   'spread': -1.7},
#  {'game_id': 13274,
#   'month': '11',
#   'away_team': 'NJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 216,
#   'home_team': 'DET',
#   'home_team_score': 5,
#   'home_team_moneyline': -236,
#   'spread': 2.0},
#  {'game_id': 13275,
#   'month': '11',
#   'away_team': 'WAS',
#   'away_team_score': 5,
#   'away_team_moneyline': 270,
#   'home_team': 'MON',
#   'home_team_score': 8,
#   'home_team_moneyline': -294,
#   'spread': 2.0},
#  {'game_id': 13276,
#   'month': '11',
#   'away_team': 'BUF',
#   'away_team_score': 3,
#   'away_team_moneyline': 259,
#   'home_team': 'OTT',
#   'home_team_score': 5,
#   'home_team_moneyline': -282,
#   'spread': 2.0},
#  {'game_id': 13277,
#   'month': '11',
#   'away_team': 'NAS',
#   'away_team_score': 5,
#   'away_team_moneyline': -294,
#   'home_team': 'TB',
#   'home_team_score': 1,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 13278,
#   'month': '11',
#   'away_team': 'VEG',
#   'away_team_score': 4,
#   'away_team_moneyline': -299,
#   'home_team': 'STL',
#   'home_team_score': 7,
#   'home_team_moneyline': 276,
#   'spread': -1.7},
#  {'game_id': 13279,
#   'month': '11',
#   'away_team': 'COL',
#   'away_team_score': 7,
#   'away_team_moneyline': -283,
#   'home_team': 'CGY',
#   'home_team_score': 8,
#   'home_team_moneyline': 260,
#   'spread': -1.7},
#  {'game_id': 13280,
#   'month': '11',
#   'away_team': 'CHI',
#   'away_team_score': 0,
#   'away_team_moneyline': -219,
#   'home_team': 'EDM',
#   'home_team_score': 5,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13281,
#   'month': '11',
#   'away_team': 'NYR',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'ANA',
#   'home_team_score': 3,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13282,
#   'month': '11',
#   'away_team': 'PHI',
#   'away_team_score': 7,
#   'away_team_moneyline': -305,
#   'home_team': 'LA',
#   'home_team_score': 3,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 13283,
#   'month': '11',
#   'away_team': 'CBJ',
#   'away_team_score': 5,
#   'away_team_moneyline': -219,
#   'home_team': 'SJ',
#   'home_team_score': 1,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13284,
#   'month': '11',
#   'away_team': 'FLA',
#   'away_team_score': 5,
#   'away_team_moneyline': -253,
#   'home_team': 'WPG',
#   'home_team_score': 3,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13285,
#   'month': '11',
#   'away_team': 'COL',
#   'away_team_score': 8,
#   'away_team_moneyline': 219,
#   'home_team': 'VAN',
#   'home_team_score': 9,
#   'home_team_moneyline': -242,
#   'spread': 2.0},
#  {'game_id': 13286,
#   'month': '11',
#   'away_team': 'CAR',
#   'away_team_score': 4,
#   'away_team_moneyline': 285,
#   'home_team': 'ARI',
#   'home_team_score': 5,
#   'home_team_moneyline': -311,
#   'spread': 2.0},
#  {'game_id': 13287,
#   'month': '11',
#   'away_team': 'OTT',
#   'away_team_score': 3,
#   'away_team_moneyline': -219,
#   'home_team': 'BUF',
#   'home_team_score': 10,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13288,
#   'month': '11',
#   'away_team': 'EDM',
#   'away_team_score': 5,
#   'away_team_moneyline': 219,
#   'home_team': 'DET',
#   'home_team_score': 4,
#   'home_team_moneyline': -242,
#   'spread': 2.0},
#  {'game_id': 13289,
#   'month': '11',
#   'away_team': 'TB',
#   'away_team_score': 5,
#   'away_team_moneyline': 230,
#   'home_team': 'MON',
#   'home_team_score': 1,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13290,
#   'month': '11',
#   'away_team': 'NJ',
#   'away_team_score': 0,
#   'away_team_moneyline': 285,
#   'home_team': 'NYI',
#   'home_team_score': 4,
#   'home_team_moneyline': -311,
#   'spread': 2.0},
#  {'game_id': 13291,
#   'month': '11',
#   'away_team': 'TOR',
#   'away_team_score': 7,
#   'away_team_moneyline': -253,
#   'home_team': 'PIT',
#   'home_team_score': 0,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13292,
#   'month': '11',
#   'away_team': 'DAL',
#   'away_team_score': 5,
#   'away_team_moneyline': -242,
#   'home_team': 'WAS',
#   'home_team_score': 4,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13293,
#   'month': '11',
#   'away_team': 'MIN',
#   'away_team_score': 7,
#   'away_team_moneyline': -288,
#   'home_team': 'STL',
#   'home_team_score': 1,
#   'home_team_moneyline': 265,
#   'spread': -1.7},
#  {'game_id': 13294,
#   'month': '11',
#   'away_team': 'BOS',
#   'away_team_score': 0,
#   'away_team_moneyline': -236,
#   'home_team': 'NAS',
#   'home_team_score': 1,
#   'home_team_moneyline': 216,
#   'spread': -1.7},
#  {'game_id': 13295,
#   'month': '11',
#   'away_team': 'CHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -265,
#   'home_team': 'CGY',
#   'home_team_score': 7,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13296,
#   'month': '11',
#   'away_team': 'CAR',
#   'away_team_score': 0,
#   'away_team_moneyline': -253,
#   'home_team': 'VEG',
#   'home_team_score': 4,
#   'home_team_moneyline': 230,
#   'spread': -1.7},
#  {'game_id': 13297,
#   'month': '11',
#   'away_team': 'CBJ',
#   'away_team_score': 1,
#   'away_team_moneyline': 276,
#   'home_team': 'LA',
#   'home_team_score': 5,
#   'home_team_moneyline': -299,
#   'spread': 2.0},
#  {'game_id': 13298,
#   'month': '11',
#   'away_team': 'PHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -185,
#   'home_team': 'SJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 174,
#   'spread': -1.7},
#  {'game_id': 13299,
#   'month': '11',
#   'away_team': 'BUF',
#   'away_team_score': 1,
#   'away_team_moneyline': -276,
#   'home_team': 'NYR',
#   'home_team_score': 4,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 13300,
#   'month': '11',
#   'away_team': 'TB',
#   'away_team_score': 5,
#   'away_team_moneyline': 167,
#   'home_team': 'OTT',
#   'home_team_score': 4,
#   'home_team_moneyline': -178,
#   'spread': 2.0},
#  {'game_id': 13301,
#   'month': '11',
#   'away_team': 'CBJ',
#   'away_team_score': 3,
#   'away_team_moneyline': -282,
#   'home_team': 'ANA',
#   'home_team_score': 4,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 13302,
#   'month': '11',
#   'away_team': 'DAL',
#   'away_team_score': 1,
#   'away_team_moneyline': -242,
#   'home_team': 'BOS',
#   'home_team_score': 3,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13303,
#   'month': '11',
#   'away_team': 'MON',
#   'away_team_score': 5,
#   'away_team_moneyline': -305,
#   'home_team': 'NYI',
#   'home_team_score': 4,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 13304,
#   'month': '11',
#   'away_team': 'NJ',
#   'away_team_score': 7,
#   'away_team_moneyline': -213,
#   'home_team': 'PIT',
#   'home_team_score': 1,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 13305,
#   'month': '11',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': -276,
#   'home_team': 'WAS',
#   'home_team_score': 5,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 13306,
#   'month': '11',
#   'away_team': 'PHI',
#   'away_team_score': 7,
#   'away_team_moneyline': -282,
#   'home_team': 'ARI',
#   'home_team_score': 3,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 13307,
#   'month': '11',
#   'away_team': 'MON',
#   'away_team_score': 4,
#   'away_team_moneyline': -317,
#   'home_team': 'NYR',
#   'home_team_score': 7,
#   'home_team_moneyline': 288,
#   'spread': -1.7},
#  {'game_id': 13308,
#   'month': '11',
#   'away_team': 'VEG',
#   'away_team_score': 1,
#   'away_team_moneyline': -265,
#   'home_team': 'TOR',
#   'home_team_score': 4,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13309,
#   'month': '11',
#   'away_team': 'DAL',
#   'away_team_score': 1,
#   'away_team_moneyline': -219,
#   'home_team': 'CBJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13310,
#   'month': '11',
#   'away_team': 'VAN',
#   'away_team_score': 3,
#   'away_team_moneyline': -288,
#   'home_team': 'DET',
#   'home_team_score': 4,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13311,
#   'month': '11',
#   'away_team': 'NJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 230,
#   'home_team': 'OTT',
#   'home_team_score': 9,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 13312,
#   'month': '11',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': -184,
#   'home_team': 'TB',
#   'home_team_score': 7,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 13313,
#   'month': '11',
#   'away_team': 'CAR',
#   'away_team_score': 1,
#   'away_team_moneyline': 285,
#   'home_team': 'STL',
#   'home_team_score': 5,
#   'home_team_moneyline': -311,
#   'spread': 2.0},
#  {'game_id': 13314,
#   'month': '11',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': -242,
#   'home_team': 'LA',
#   'home_team_score': 5,
#   'home_team_moneyline': 219,
#   'spread': -1.7},
#  {'game_id': 13315,
#   'month': '11',
#   'away_team': 'MIN',
#   'away_team_score': 4,
#   'away_team_moneyline': -219,
#   'home_team': 'SJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 201,
#   'spread': -1.7},
#  {'game_id': 13316,
#   'month': '11',
#   'away_team': 'PIT',
#   'away_team_score': 1,
#   'away_team_moneyline': -265,
#   'home_team': 'WAS',
#   'home_team_score': 3,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 13317,
#   'month': '11',
#   'away_team': 'NAS',
#   'away_team_score': 5,
#   'away_team_moneyline': 282,
#   'home_team': 'COL',
#   'home_team_score': 1,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 13318,
#   'month': '11',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': 242,
#   'home_team': 'ANA',
#   'home_team_score': 4,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 13319,
#   'month': '11',
#   'away_team': 'VAN',
#   'away_team_score': 11,
#   'away_team_moneyline': -144,
#   'home_team': 'BOS',
#   'home_team_score': 7,
#   'home_team_moneyline': 132,
#   'spread': -1.7},
#  {'game_id': 13320,
#   'month': '11',
#   'away_team': 'ARI',
#   'away_team_score': 5,
#   'away_team_moneyline': -270,
#   'home_team': 'PHI',
#   'home_team_score': 7,
#   'home_team_moneyline': 247,
#   'spread': -1.7},
#  {'game_id': 13321,
#   'month': '11',
#   'away_team': 'EDM',
#   'away_team_score': 1,
#   'away_team_moneyline': -230,
#   'home_team': 'FLA',
#   'home_team_score': 5,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 13322,
#   'month': '11',
#   'away_team': 'BUF',
#   'away_team_score': 8,
#   'away_team_moneyline': -270,
#   'home_team': 'MON',
#   'home_team_score': 7,
#   'home_team_moneyline': 247,
#   'spread': -1.7},
#  {'game_id': 13323,
#   'month': '11',
# ...
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'EDM',
#   'home_team_score': 3,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 14017,
#   'month': '02',
#   'away_team': 'CHI',
#   'away_team_score': 7,
#   'away_team_moneyline': -265,
#   'home_team': 'DET',
#   'home_team_score': 5,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 14018,
#   'month': '02',
#   'away_team': 'WPG',
#   'away_team_score': 1,
#   'away_team_moneyline': -299,
#   'home_team': 'COL',
#   'home_team_score': 9,
#   'home_team_moneyline': 276,
#   'spread': -1.7},
#  {'game_id': 14019,
#   'month': '02',
#   'away_team': 'NYI',
#   'away_team_score': 3,
#   'away_team_moneyline': -245,
#   'home_team': 'CGY',
#   'home_team_score': 5,
#   'home_team_moneyline': 222,
#   'spread': -1.7},
#  {'game_id': 14020,
#   'month': '02',
#   'away_team': 'BOS',
#   'away_team_score': 4,
#   'away_team_moneyline': -236,
#   'home_team': 'VEG',
#   'home_team_score': 3,
#   'home_team_moneyline': 216,
#   'spread': -1.7},
#  {'game_id': 14021,
#   'month': '02',
#   'away_team': 'OTT',
#   'away_team_score': 0,
#   'away_team_moneyline': -230,
#   'home_team': 'NJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 14022,
#   'month': '02',
#   'away_team': 'MIN',
#   'away_team_score': 5,
#   'away_team_moneyline': -305,
#   'home_team': 'NYR',
#   'home_team_score': 1,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 14023,
#   'month': '02',
#   'away_team': 'SJ',
#   'away_team_score': 5,
#   'away_team_moneyline': -282,
#   'home_team': 'PIT',
#   'home_team_score': 0,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 14024,
#   'month': '02',
#   'away_team': 'WAS',
#   'away_team_score': 4,
#   'away_team_moneyline': -167,
#   'home_team': 'TOR',
#   'home_team_score': 3,
#   'home_team_moneyline': 155,
#   'spread': -1.7},
#  {'game_id': 14025,
#   'month': '02',
#   'away_team': 'CAR',
#   'away_team_score': 5,
#   'away_team_moneyline': 294,
#   'home_team': 'FLA',
#   'home_team_score': 4,
#   'home_team_moneyline': -322,
#   'spread': 2.0},
#  {'game_id': 14026,
#   'month': '02',
#   'away_team': 'PHI',
#   'away_team_score': 1,
#   'away_team_moneyline': -224,
#   'home_team': 'MON',
#   'home_team_score': 7,
#   'home_team_moneyline': 207,
#   'spread': -1.7},
#  {'game_id': 14027,
#   'month': '02',
#   'away_team': 'BUF',
#   'away_team_score': 1,
#   'away_team_moneyline': 115,
#   'home_team': 'TB',
#   'home_team_score': 3,
#   'home_team_moneyline': -127,
#   'spread': -1.7},
#  {'game_id': 14028,
#   'month': '02',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -150,
#   'home_team': 'NAS',
#   'home_team_score': 3,
#   'home_team_moneyline': 138,
#   'spread': -1.7},
#  {'game_id': 14029,
#   'month': '02',
#   'away_team': 'STL',
#   'away_team_score': 3,
#   'away_team_moneyline': 282,
#   'home_team': 'DAL',
#   'home_team_score': 7,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 14030,
#   'month': '02',
#   'away_team': 'NYI',
#   'away_team_score': 4,
#   'away_team_moneyline': 281,
#   'home_team': 'EDM',
#   'home_team_score': 5,
#   'home_team_moneyline': -304,
#   'spread': 2.0},
#  {'game_id': 14031,
#   'month': '02',
#   'away_team': 'ARI',
#   'away_team_score': 4,
#   'away_team_moneyline': -282,
#   'home_team': 'VAN',
#   'home_team_score': 3,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 14032,
#   'month': '02',
#   'away_team': 'CBJ',
#   'away_team_score': 4,
#   'away_team_moneyline': 138,
#   'home_team': 'OTT',
#   'home_team_score': 0,
#   'home_team_moneyline': -150,
#   'spread': 2.0},
#  {'game_id': 14033,
#   'month': '02',
#   'away_team': 'COL',
#   'away_team_score': 7,
#   'away_team_moneyline': 230,
#   'home_team': 'CHI',
#   'home_team_score': 4,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 14034,
#   'month': '02',
#   'away_team': 'MIN',
#   'away_team_score': 4,
#   'away_team_moneyline': -317,
#   'home_team': 'DET',
#   'home_team_score': 3,
#   'home_team_moneyline': 288,
#   'spread': -1.7},
#  {'game_id': 14035,
#   'month': '02',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': -130,
#   'home_team': 'CGY',
#   'home_team_score': 3,
#   'home_team_moneyline': 119,
#   'spread': -1.7},
#  {'game_id': 14036,
#   'month': '02',
#   'away_team': 'WPG',
#   'away_team_score': 8,
#   'away_team_moneyline': -213,
#   'home_team': 'VEG',
#   'home_team_score': 4,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 14037,
#   'month': '02',
#   'away_team': 'WAS',
#   'away_team_score': 3,
#   'away_team_moneyline': 246,
#   'home_team': 'BUF',
#   'home_team_score': 7,
#   'home_team_moneyline': -269,
#   'spread': 2.0},
#  {'game_id': 14038,
#   'month': '02',
#   'away_team': 'NJ',
#   'away_team_score': 3,
#   'away_team_moneyline': -247,
#   'home_team': 'NYR',
#   'home_team_score': 7,
#   'home_team_moneyline': 224,
#   'spread': -1.7},
#  {'game_id': 14039,
#   'month': '02',
#   'away_team': 'BOS',
#   'away_team_score': 1,
#   'away_team_moneyline': -265,
#   'home_team': 'STL',
#   'home_team_score': 3,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 14040,
#   'month': '02',
#   'away_team': 'CAR',
#   'away_team_score': 4,
#   'away_team_moneyline': -345,
#   'home_team': 'DAL',
#   'home_team_score': 0,
#   'home_team_moneyline': 311,
#   'spread': -1.7},
#  {'game_id': 14041,
#   'month': '02',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -201,
#   'home_team': 'FLA',
#   'home_team_score': 8,
#   'home_team_moneyline': 190,
#   'spread': -1.7},
#  {'game_id': 14042,
#   'month': '02',
#   'away_team': 'SJ',
#   'away_team_score': 0,
#   'away_team_moneyline': 236,
#   'home_team': 'CBJ',
#   'home_team_score': 5,
#   'home_team_moneyline': -259,
#   'spread': 2.0},
#  {'game_id': 14043,
#   'month': '02',
#   'away_team': 'COL',
#   'away_team_score': 7,
#   'away_team_moneyline': -167,
#   'home_team': 'NAS',
#   'home_team_score': 0,
#   'home_team_moneyline': 155,
#   'spread': -1.7},
#  {'game_id': 14044,
#   'month': '02',
#   'away_team': 'MON',
#   'away_team_score': 4,
#   'away_team_moneyline': -177,
#   'home_team': 'TOR',
#   'home_team_score': 8,
#   'home_team_moneyline': 166,
#   'spread': -1.7},
#  {'game_id': 14045,
#   'month': '02',
#   'away_team': 'PIT',
#   'away_team_score': 4,
#   'away_team_moneyline': 219,
#   'home_team': 'PHI',
#   'home_team_score': 5,
#   'home_team_moneyline': -242,
#   'spread': 2.0},
#  {'game_id': 14046,
#   'month': '02',
#   'away_team': 'ANA',
#   'away_team_score': 1,
#   'away_team_moneyline': -224,
#   'home_team': 'EDM',
#   'home_team_score': 3,
#   'home_team_moneyline': 207,
#   'spread': -1.7},
#  {'game_id': 14047,
#   'month': '02',
#   'away_team': 'NYI',
#   'away_team_score': 5,
#   'away_team_moneyline': 253,
#   'home_team': 'VAN',
#   'home_team_score': 0,
#   'home_team_moneyline': -276,
#   'spread': 2.0},
#  {'game_id': 14048,
#   'month': '02',
#   'away_team': 'NYR',
#   'away_team_score': 7,
#   'away_team_moneyline': -167,
#   'home_team': 'WAS',
#   'home_team_score': 8,
#   'home_team_moneyline': 155,
#   'spread': -1.7},
#  {'game_id': 14049,
#   'month': '02',
#   'away_team': 'DAL',
#   'away_team_score': 5,
#   'away_team_moneyline': 311,
#   'home_team': 'CHI',
#   'home_team_score': 4,
#   'home_team_moneyline': -345,
#   'spread': 2.0},
#  {'game_id': 14050,
#   'month': '02',
#   'away_team': 'SJ',
#   'away_team_score': 7,
#   'away_team_moneyline': 161,
#   'home_team': 'DET',
#   'home_team_score': 4,
#   'home_team_moneyline': -173,
#   'spread': 2.0},
#  {'game_id': 14051,
#   'month': '02',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': -121,
#   'home_team': 'OTT',
#   'home_team_score': 1,
#   'home_team_moneyline': -121,
#   'spread': 2.0},
#  {'game_id': 14052,
#   'month': '02',
#   'away_team': 'STL',
#   'away_team_score': 1,
#   'away_team_moneyline': -282,
#   'home_team': 'MIN',
#   'home_team_score': 3,
#   'home_team_moneyline': 259,
#   'spread': -1.7},
#  {'game_id': 14053,
#   'month': '02',
#   'away_team': 'WPG',
#   'away_team_score': 1,
#   'away_team_moneyline': 230,
#   'home_team': 'ARI',
#   'home_team_score': 5,
#   'home_team_moneyline': -253,
#   'spread': 2.0},
#  {'game_id': 14054,
#   'month': '02',
#   'away_team': 'MON',
#   'away_team_score': 1,
#   'away_team_moneyline': 212,
#   'home_team': 'NJ',
#   'home_team_score': 3,
#   'home_team_moneyline': -229,
#   'spread': 2.0},
#  {'game_id': 14055,
#   'month': '02',
#   'away_team': 'BUF',
#   'away_team_score': 4,
#   'away_team_moneyline': -135,
#   'home_team': 'TOR',
#   'home_team_score': 7,
#   'home_team_moneyline': 123,
#   'spread': -1.7},
#  {'game_id': 14056,
#   'month': '02',
#   'away_team': 'LA',
#   'away_team_score': 4,
#   'away_team_moneyline': 147,
#   'home_team': 'TB',
#   'home_team_score': 5,
#   'home_team_moneyline': -159,
#   'spread': -1.7},
#  {'game_id': 14057,
#   'month': '02',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': -135,
#   'home_team': 'NAS',
#   'home_team_score': 4,
#   'home_team_moneyline': 123,
#   'spread': -1.7},
#  {'game_id': 14058,
#   'month': '02',
#   'away_team': 'FLA',
#   'away_team_score': 5,
#   'away_team_moneyline': -230,
#   'home_team': 'COL',
#   'home_team_score': 4,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 14059,
#   'month': '02',
#   'away_team': 'ANA',
#   'away_team_score': 0,
#   'away_team_moneyline': -227,
#   'home_team': 'VAN',
#   'home_team_score': 5,
#   'home_team_moneyline': 209,
#   'spread': -1.7},
#  {'game_id': 14060,
#   'month': '02',
#   'away_team': 'SJ',
#   'away_team_score': 1,
#   'away_team_moneyline': 282,
#   'home_team': 'BOS',
#   'home_team_score': 5,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 14061,
#   'month': '02',
#   'away_team': 'LA',
#   'away_team_score': 1,
#   'away_team_moneyline': -127,
#   'home_team': 'CAR',
#   'home_team_score': 8,
#   'home_team_moneyline': 115,
#   'spread': -1.7},
#  {'game_id': 14062,
#   'month': '02',
#   'away_team': 'CGY',
#   'away_team_score': 4,
#   'away_team_moneyline': -299,
#   'home_team': 'NYI',
#   'home_team_score': 1,
#   'home_team_moneyline': 276,
#   'spread': -1.7},
#  {'game_id': 14063,
#   'month': '02',
#   'away_team': 'BUF',
#   'away_team_score': 3,
#   'away_team_moneyline': -208,
#   'home_team': 'PHI',
#   'home_team_score': 7,
#   'home_team_moneyline': 195,
#   'spread': -1.7},
#  {'game_id': 14064,
#   'month': '02',
#   'away_team': 'OTT',
#   'away_team_score': 3,
#   'away_team_moneyline': 127,
#   'home_team': 'WAS',
#   'home_team_score': 9,
#   'home_team_moneyline': -138,
#   'spread': -1.7},
#  {'game_id': 14065,
#   'month': '02',
#   'away_team': 'PIT',
#   'away_team_score': 7,
#   'away_team_moneyline': -213,
#   'home_team': 'CBJ',
#   'home_team_score': 3,
#   'home_team_moneyline': 196,
#   'spread': -1.7},
#  {'game_id': 14066,
#   'month': '02',
#   'away_team': 'MON',
#   'away_team_score': 11,
#   'away_team_moneyline': 247,
#   'home_team': 'DET',
#   'home_team_score': 1,
#   'home_team_moneyline': -270,
#   'spread': 2.0},
#  {'game_id': 14067,
#   'month': '02',
#   'away_team': 'NAS',
#   'away_team_score': 0,
#   'away_team_moneyline': -233,
#   'home_team': 'STL',
#   'home_team_score': 3,
#   'home_team_moneyline': 215,
#   'spread': -1.7},
#  {'game_id': 14068,
#   'month': '02',
#   'away_team': 'MIN',
#   'away_team_score': 4,
#   'away_team_moneyline': -230,
#   'home_team': 'WPG',
#   'home_team_score': 3,
#   'home_team_moneyline': 213,
#   'spread': -1.7},
#  {'game_id': 14069,
#   'month': '02',
#   'away_team': 'FLA',
#   'away_team_score': 4,
#   'away_team_moneyline': -259,
#   'home_team': 'ARI',
#   'home_team_score': 5,
#   'home_team_moneyline': 236,
#   'spread': -1.7},
#  {'game_id': 14070,
#   'month': '02',
#   'away_team': 'DAL',
#   'away_team_score': 1,
#   'away_team_moneyline': -165,
#   'home_team': 'VEG',
#   'home_team_score': 5,
#   'home_team_moneyline': 153,
#   'spread': -1.7},
#  {'game_id': 14071,
#   'month': '02',
#   'away_team': 'CGY',
#   'away_team_score': 3,
#   'away_team_moneyline': 155,
#   'home_team': 'NJ',
#   'home_team_score': 1,
#   'home_team_moneyline': -167,
#   'spread': 2.0},
#  {'game_id': 14072,
#   'month': '02',
#   'away_team': 'EDM',
#   'away_team_score': 3,
#   'away_team_moneyline': -139,
#   'home_team': 'TOR',
#   'home_team_score': 8,
#   'home_team_moneyline': 128,
#   'spread': -1.7},
#  {'game_id': 14073,
#   'month': '02',
#   'away_team': 'TB',
#   'away_team_score': 5,
#   'away_team_moneyline': 144,
#   'home_team': 'NYR',
#   'home_team_score': 4,
#   'home_team_moneyline': -155,
#   'spread': 2.0},
#  {'game_id': 14074,
#   'month': '02',
#   'away_team': 'VAN',
#   'away_team_score': 3,
#   'away_team_moneyline': -184,
#   'home_team': 'COL',
#   'home_team_score': 4,
#   'home_team_moneyline': 173,
#   'spread': -1.7},
#  {'game_id': 14075,
#   'month': '02',
#   'away_team': 'CHI',
#   'away_team_score': 5,
#   'away_team_moneyline': 253,
#   'home_team': 'ANA',
#   'home_team_score': 4,
#   'home_team_moneyline': -276,
#   'spread': 2.0},
#  {'game_id': 14076,
#   'month': '02',
#   'away_team': 'TB',
#   'away_team_score': 1,
#   'away_team_moneyline': -265,
#   'home_team': 'BOS',
#   'home_team_score': 5,
#   'home_team_moneyline': 242,
#   'spread': -1.7},
#  {'game_id': 14077,
#   'month': '02',
#   'away_team': 'TOR',
#   'away_team_score': 1,
#   'away_team_moneyline': -294,
#   'home_team': 'NYI',
#   'home_team_score': 8,
#   'home_team_moneyline': 270,
#   'spread': -1.7},
#  {'game_id': 14078,
#   'month': '02',
#   'away_team': 'PHI',
#   'away_team_score': 4,
#   'away_team_moneyline': -190,
#   'home_team': 'CBJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 178,
#   'spread': -1.7},
#  {'game_id': 14079,
#   'month': '02',
#   'away_team': 'EDM',
#   'away_team_score': 5,
#   'away_team_moneyline': 215,
#   'home_team': 'OTT',
#   'home_team_score': 3,
#   'home_team_moneyline': -233,
#   'spread': 2.0},
#  {'game_id': 14080,
#   'month': '02',
#   'away_team': 'VAN',
#   'away_team_score': 3,
#   'away_team_moneyline': -201,
#   'home_team': 'ARI',
#   'home_team_score': 7,
#   'home_team_moneyline': 190,
#   'spread': -1.7},
#  {'game_id': 14081,
#   'month': '02',
#   'away_team': 'FLA',
#   'away_team_score': 7,
#   'away_team_moneyline': -167,
#   'home_team': 'VEG',
#   'home_team_score': 8,
#   'home_team_moneyline': 155,
#   'spread': -1.7},
#  {'game_id': 14082,
#   'month': '02',
#   'away_team': 'DAL',
#   'away_team_score': 5,
#   'away_team_moneyline': 294,
#   'home_team': 'LA',
#   'home_team_score': 4,
#   'home_team_moneyline': -322,
#   'spread': 2.0},
#  {'game_id': 14083,
#   'month': '03',
#   'away_team': 'PIT',
#   'away_team_score': 4,
#   'away_team_moneyline': 219,
#   'home_team': 'BUF',
#   'home_team_score': 5,
#   'home_team_moneyline': -242,
#   'spread': 2.0},
#  {'game_id': 14084,
#   'month': '03',
#   'away_team': 'PHI',
#   'away_team_score': 8,
#   'away_team_moneyline': 247,
#   'home_team': 'NJ',
#   'home_team_score': 4,
#   'home_team_moneyline': -270,
#   'spread': 2.0},
#  {'game_id': 14085,
#   'month': '03',
#   'away_team': 'WAS',
#   'away_team_score': 4,
#   'away_team_moneyline': -305,
#   'home_team': 'NYI',
#   'home_team_score': 1,
#   'home_team_moneyline': 282,
#   'spread': -1.7},
#  {'game_id': 14086,
#   'month': '03',
#   'away_team': 'MON',
#   'away_team_score': 5,
#   'away_team_moneyline': 242,
#   'home_team': 'NYR',
#   'home_team_score': 3,
#   'home_team_moneyline': -265,
#   'spread': 2.0},
#  {'game_id': 14087,
#   'month': '03',
#   'away_team': 'STL',
#   'away_team_score': 3,
#   'away_team_moneyline': -276,
#   'home_team': 'CAR',
#   'home_team_score': 7,
#   'home_team_moneyline': 253,
#   'spread': -1.7},
#  {'game_id': 14088,
#   'month': '03',
#   'away_team': 'NAS',
#   'away_team_score': 4,
#   'away_team_moneyline': 282,
#   'home_team': 'WPG',
#   'home_team_score': 7,
#   'home_team_moneyline': -305,
#   'spread': 2.0},
#  {'game_id': 14089,
#   'month': '03',
#   'away_team': 'VEG',
#   'away_team_score': 4,
#   'away_team_moneyline': 175,
#   'home_team': 'ANA',
#   'home_team_score': 0,
#   'home_team_moneyline': -186,
#   'spread': 2.0},
#  {'game_id': 14090,
#   'month': '03',
#   'away_team': 'COL',
#   'away_team_score': 4,
#   'away_team_moneyline': -197,
#   'home_team': 'SJ',
#   'home_team_score': 5,
#   'home_team_moneyline': 185,
#   'spread': -1.7},
#  {'game_id': 14091,
#   'month': '03',
#   'away_team': 'EDM',
#   'away_team_score': 5,
#   'away_team_moneyline': -155,
#   'home_team': 'CBJ',
#   'home_team_score': 0,
#   'home_team_moneyline': 144,
#   'spread': -1.7},
#  {'game_id': 14092,
#   'month': '03',
#   'away_team': 'CHI',
#   'away_team_score': 4,
#   'away_team_moneyline': 259,
#   'home_team': 'LA',
#   'home_team_score': 8,
#   'home_team_moneyline': -282,
#   'spread': 2.0},
#  ...]

# %% [markdown]
# ## Creating NHL Table

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %%
# cursor.execute("""
# CREATE DATABASE MLB
# """)

# cursor.close()
# cnx.close()

# %%
cursor.execute("""
    CREATE TABLE nba (
    game_id varchar(11) NOT NULL primary key,
    month varchar(2) not null,
    away_team varchar(11) not null,
    away_team_score int(3) not null,
    home_team varchar(11) not null,
    home_team_score int(3) not null,
    away_team_moneyline int(4) not null,
    home_team_moneyline int(4) not null,
    spread float(5) not null
    )
""")

# %% [markdown]
# ## Inserting to table

# %%
nba_games_to_insert = []

for game in parsed_games_nba:

    nba_game_to_insert = (
        game['game_id'], 
        game['month'], 
        game['away_team'],
        game['away_team_score'],
        game['home_team'], 
        game['home_team_score'],
        game['away_team_moneyline'],
        game['home_team_moneyline'],
        game['spread'] 
    )
    
    nba_games_to_insert.append(nba_game_to_insert)

# %%
insert_query = """
    INSERT INTO nba (
            game_id,
            month,
            away_team,
            away_team_score,
            home_team,
            home_team_score,
            away_team_moneyline,
            home_team_moneyline,
            spread
        )
    VALUES (
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s,
            # %s
        )
"""
cursor.executemany(insert_query, nba_games_to_insert)
cnx.commit()

# %% [markdown]
# ### Questions (Null Hypothesis)

# %% [markdown]
# Is there a "home field" advantage(in general , 2018 season)?
#
# Will a home team preform better (by month)?
#
# If home team cover more than away team ("good teams win, great teams cover")?

# %% [markdown]
# ## Creating MLB DataFrame

# %%
cnx = mysql.connector.connect(
    host = config.host,
    user = config.user,
    password = config.password,
    database = 'sports'
)
cursor = cnx.cursor(buffered=True)

# %%
cursor.execute(  """SELECT * FROM nba
                    order by game_id;""")
#assigning database (pointed in MySql) as a dataframe using pandas                         
df_nba = pd.DataFrame(cursor.fetchall())


#assigning the column names 
df_nba.columns=['game_id','month', 'away_team', 'away_team_score', 'home_team', 'home_team_score', 'away_team_moneyline', 'home_team_moneyline', 'spread']

# %%
df_nba
# Out:
#      game_id month away_team  away_team_score home_team  home_team_score  \
# 0      13093    10       PHI                9       OTT                5
# 1      13094    10       VEG                3       WAS                7
# 2      13095    10       ARI                4       ANA                3
# 3      13096    10       MON                3       TOR                4
# 4      13097    10       BOS                0       WAS                9
# 5      13098    10       CGY                3       VAN                7
# 6      13099    10       ANA                7        SJ                3
# 7      13100    10       BOS                5       BUF                0
# 8      13101    10       NYI                3       CAR                1
# 9      13102    10       NAS                4       NYR                3
# 10     13103    10       WAS                8       PIT                9
# 11     13104    10       CBJ                4       DET                3
# 12     13105    10       CHI                5       OTT                4
# 13     13106    10       WPG                7       STL                1
# 14     13107    10       ARI                0       DAL                4
# 15     13108    10       MIN                1       COL                5
# 16     13109    10       PHI                7       VEG                3
# 17     13110    10       CAR                4       CBJ                1
# 18     13111    10        SJ                4        LA                3
# 19     13112    10       EDM                3        NJ                7
# 20     13113    10       NYR                1       BUF                4
# 21     13114    10       WPG                1       DAL                7
# 22     13115    10       NAS                5       NYI                4
# 23     13116    10       MON                7       PIT                1
# 24     13117    10       FLA                1        TB                3
# 25     13118    10       OTT                7       TOR                4
# 26     13119    10       CHI                7       STL                5
# 27     13120    10       VEG                3       MIN                1
# 28     13121    10       VAN                5       CGY                9
# 29     13122    10       PHI                3       COL                7
# ...      ...   ...       ...              ...       ...              ...
# 1241   14334    04       OTT                3       BUF                7
# 1242   14335    04        NJ                1       CAR                4
# 1243   14336    04       DET                1       PIT                5
# 1244   14337    04        TB                4       TOR                1
# 1245   14338    04       MON                1       WAS                3
# 1246   14339    04       NYI                3       FLA                1
# 1247   14340    04       PHI                4       STL                9
# 1248   14341    04       VAN                3       NAS                4
# 1249   14342    04       BOS                4       MIN                0
# 1250   14343    04        SJ                4       EDM                3
# 1251   14344    04       WPG                3       COL                4
# 1252   14345    04       ARI                5       VEG                1
# 1253   14346    04       CBJ                4       NYR                3
# 1254   14347    04       DAL                1       CHI                8
# 1255   14348    04        LA                3       ANA                7
# 1256   14349    04        TB                8       BOS                4
# 1257   14350    04       VAN                3       STL                4
# 1258   14351    04       BUF                9       DET                1
# 1259   14352    04       TOR                7       MON                8
# 1260   14353    04       CBJ                8       OTT                3
# 1261   14354    04       CAR                5       PHI                4
# 1262   14355    04       NYR                5       PIT                4
# 1263   14356    04       NYI                4       WAS                0
# 1264   14357    04        NJ                5       FLA                4
# 1265   14358    04       MIN                0       DAL                4
# 1266   14359    04       CHI                3       NAS                7
# 1267   14360    04       EDM                4       CGY                1
# 1268   14361    04       WPG                5       ARI                3
# 1269   14362    04       VEG                3        LA                7
# 1270   14363    04       COL                3        SJ                7
#
#       away_team_moneyline  home_team_moneyline  spread
# 0                     242                 -265     2.0
# 1                    -242                  219    -1.7
# 2                    -236                  216    -1.7
# 3                    -144                  132    -1.7
# 4                    -306                  283    -1.7
# 5                     242                 -265     2.0
# 6                    -196                  184    -1.7
# 7                     230                 -253     2.0
# 8                    -219                  201    -1.7
# 9                     213                 -230     2.0
# 10                   -219                  201    -1.7
# 11                    224                 -247     2.0
# 12                    270                 -294     2.0
# 13                   -351                  317    -1.7
# 14                   -190                  178    -1.7
# 15                   -322                  294    -1.7
# 16                   -213                  196    -1.7
# 17                   -230                  213    -1.7
# 18                    282                 -305     2.0
# 19                    294                 -322     2.0
# 20                   -274                  251    -1.7
# 21                    299                 -334     2.0
# 22                    224                 -247     2.0
# 23                   -155                  144    -1.7
# 24                   -196                  184    -1.7
# 25                    115                 -127    -1.7
# 26                   -204                  191    -1.7
# 27                   -298                  275    -1.7
# 28                   -184                  173    -1.7
# 29                   -322                  294    -1.7
# ...                   ...                  ...     ...
# 1241                 -143                  115    -1.2
# 1242                 -120                 -136    -1.7
# 1243                  115                 -140    -1.7
# 1244                  216                 -276     1.3
# 1245                 -224                  178    -1.2
# 1246                  216                 -276     1.3
# 1247                 -143                  115    -1.2
# 1248                 -144                  117    -1.7
# 1249                 -270                  213    -1.2
# 1250                  159                 -201     1.3
# 1251                 -265                  207    -1.2
# 1252                 -146                  120    -1.2
# 1253                  117                 -144     2.0
# 1254                  259                 -340     2.0
# 1255                 -253                  196    -1.7
# 1256                 -320                  253    -1.7
# 1257                 -136                 -121    -1.7
# 1258                 -317                  242    -1.7
# 1259                 -351                  270    -1.7
# 1260                  155                 -192     2.0
# 1261                  201                 -253     2.0
# 1262                  115                 -143    -1.7
# 1263                 -305                  236    -1.7
# 1264                 -173                  142    -1.7
# 1265                 -259                  201    -1.7
# 1266                 -154                  124    -1.7
# 1267                 -183                  150    -1.7
# 1268                  219                 -276     2.0
# 1269                  201                 -253     2.0
# 1270                 -224                  178    -1.7
#
# [1271 rows x 9 columns]
